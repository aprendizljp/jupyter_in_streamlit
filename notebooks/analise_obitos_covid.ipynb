# %%
# Importing required libs
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Defining file paths
caminho_2019 = "../data/obitos-2019.csv"
caminho_2020 = "../data/obitos-2020.csv"
caminho_2021 = "../data/obitos-2021.csv"

# Reading data from files
dados_2019 = pd.read_csv(caminho_2019)
dados_2020 = pd.read_csv(caminho_2020)
dados_2021 = pd.read_csv(caminho_2021)

# %%
# Investigating the imported data
print(f'2019 {dados_2019.shape}')
print(f'2020 {dados_2020.shape}')
print(f'2021 {dados_2021.shape}')

print('\n')
print(dados_2019.info())
print('\n')
print(dados_2020.info())
print('\n')
print(dados_2021.info())
# Out:
# 2019 (12453, 6)
# 2020 (15033, 6)
# 2021 (10090, 6)
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12453 entries, 0 to 12452
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   uf            12453 non-null  object
#  1   tipo_doenca   12453 non-null  object
#  2   local_obito   12453 non-null  object
#  3   faixa_etaria  12453 non-null  object
#  4   sexo          12449 non-null  object
#  5   total         12453 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 583.9+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15033 entries, 0 to 15032
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   uf            15033 non-null  object
#  1   tipo_doenca   15033 non-null  object
#  2   local_obito   15033 non-null  object
#  3   faixa_etaria  15033 non-null  object
#  4   sexo          15032 non-null  object
#  5   total         15033 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 704.8+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10090 entries, 0 to 10089
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   uf            10090 non-null  object
#  1   tipo_doenca   10090 non-null  object
#  2   local_obito   10090 non-null  object
#  3   faixa_etaria  10090 non-null  object
#  4   sexo          10090 non-null  object
#  5   total         10090 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 473.1+ KB
# None

# %%
print('\n2019:')
display(dados_2019.sample(5))
print(f'ufs: {len(dados_2019["uf"].unique())}')
print(f'tipo_doenca:\n {dados_2019["tipo_doenca"].unique()}')

print('\n2020:')
display(dados_2020.sample(5))
print(f'ufs: {len(dados_2020["uf"].unique())}')
print(f'tipo_doenca:\n {dados_2020["tipo_doenca"].unique()}')

print('\n2021:')
display(dados_2021.sample(5))
print(f'ufs: {len(dados_2021["uf"].unique())}')
print(f'tipo_doenca:\n {dados_2021["tipo_doenca"].unique()}')
# Out:
# 2019:
#       uf tipo_doenca            local_obito faixa_etaria sexo  total
# 8570  BA  SEPTICEMIA  OUTROS_SERVICOS_SAUDE      80 - 89    F     50
# 6042  ES      OUTRAS                  OUTRO      60 - 69    F      8
# 6746  RS      OUTRAS              DOMICILIO      60 - 69    I      2
# 8272  SP      OUTRAS                   SAMU      70 - 79    M      2
# 2439  SP      OUTRAS               HOSPITAL      20 - 29    M   1411
# ufs: 27
# tipo_doenca:
#  ['OUTRAS' 'INDETERMINADA' 'INSUFICIENCIA_RESPIRATORIA' 'PNEUMONIA'
#  'SEPTICEMIA' 'SRAG']
#
# 2020:
#        uf                 tipo_doenca            local_obito faixa_etaria  \
# 9564   PR                      OUTRAS            POSTO_SAUDE      70 - 79
# 10194  AC  INSUFICIENCIA_RESPIRATORIA              DOMICILIO      80 - 89
# 14938  SE                  SEPTICEMIA               HOSPITAL          N/I
# 8783   CE                       COVID  OUTROS_SERVICOS_SAUDE      70 - 79
# 3753   RS  INSUFICIENCIA_RESPIRATORIA                  OUTRO      30 - 39
#
#       sexo  total
# 9564     F      1
# 10194    M      5
# 14938    M      8
# 8783     F     93
# 3753     F      1
# ufs: 27
# tipo_doenca:
#  ['OUTRAS' 'COVID' 'INDETERMINADA' 'INSUFICIENCIA_RESPIRATORIA' 'PNEUMONIA'
#  'SEPTICEMIA' 'SRAG']
#
# 2021:
#       uf                 tipo_doenca            local_obito faixa_etaria sexo  \
# 8467  ES                        SRAG               HOSPITAL      90 - 99    F
# 4125  PR                       COVID              DOMICILIO      50 - 59    F
# 4213  RJ                  SEPTICEMIA               HOSPITAL      50 - 59    M
# 4144  PR  INSUFICIENCIA_RESPIRATORIA               HOSPITAL      50 - 59    M
# 5015  MG                        SRAG  OUTROS_SERVICOS_SAUDE      60 - 69    F
#
#       total
# 8467      3
# 4125      7
# 4213    182
# 4144     38
# 5015      1
# ufs: 27
# tipo_doenca:
#  ['OUTRAS' 'COVID' 'INDETERMINADA' 'INSUFICIENCIA_RESPIRATORIA' 'PNEUMONIA'
#  'SEPTICEMIA' 'SRAG']

# %%
deaths_by_type_2019 = dados_2019.groupby('tipo_doenca')['total'].sum()

print('\n2019')
print(deaths_by_type_2019)

deaths_by_type_2020 = dados_2020.groupby('tipo_doenca')['total'].sum()
print('\n2020')
print(deaths_by_type_2020)

deaths_by_type_2021 = dados_2021.groupby('tipo_doenca')['total'].sum()
print('\n2021')
print(deaths_by_type_2021)
# Out:
# 2019
# tipo_doenca
# INDETERMINADA                   7029
# INSUFICIENCIA_RESPIRATORIA    101131
# OUTRAS                        664026
# PNEUMONIA                     227051
# SEPTICEMIA                    176179
# SRAG                            1505
# Name: total, dtype: int64
#
# 2020
# tipo_doenca
# COVID                         197407
# INDETERMINADA                   9807
# INSUFICIENCIA_RESPIRATORIA     99865
# OUTRAS                        697457
# PNEUMONIA                     183394
# SEPTICEMIA                    164049
# SRAG                           16695
# Name: total, dtype: int64
#
# 2021
# tipo_doenca
# COVID                         102815
# INDETERMINADA                   2248
# INSUFICIENCIA_RESPIRATORIA     19643
# OUTRAS                        145322
# PNEUMONIA                      35793
# SEPTICEMIA                     34942
# SRAG                            3481
# Name: total, dtype: int64

# %%
proportion_20_19 = deaths_by_type_2020 / deaths_by_type_2019
proportion_20_19
# Out:
# tipo_doenca
# COVID                               NaN
# INDETERMINADA                  1.395220
# INSUFICIENCIA_RESPIRATORIA     0.987482
# OUTRAS                         1.050346
# PNEUMONIA                      0.807722
# SEPTICEMIA                     0.931150
# SRAG                          11.093023
# Name: total, dtype: float64

# %%
proportion_21_20 = deaths_by_type_2021 * 85 / (deaths_by_type_2020 * 365)
proportion_21_20
# Out:
# tipo_doenca
# COVID                         0.121289
# INDETERMINADA                 0.053381
# INSUFICIENCIA_RESPIRATORIA    0.045806
# OUTRAS                        0.048522
# PNEUMONIA                     0.045451
# SEPTICEMIA                    0.049602
# SRAG                          0.048556
# Name: total, dtype: float64

# %%
def comparison_chart(causa_mortis):

    deaths_by_type_2019 = dados_2019.groupby('tipo_doenca')['total'].sum()
    deaths_by_type_2020 = dados_2020.groupby('tipo_doenca')['total'].sum()
    deaths_by_type_2021 = dados_2021.groupby('tipo_doenca')['total'].sum()

    if(causa_mortis == 'COVID'):
        selection_2019 = 0
    else:
        selection_2019 = int(deaths_by_type_2019.loc[causa_mortis])

    selection_2020 = int(deaths_by_type_2020.loc[causa_mortis])
    selection_2021 = int(deaths_by_type_2021.loc[causa_mortis])
    selection_by_causa_mortis = [selection_2019, selection_2020, selection_2021]

    death_df = pd.DataFrame({'Total': selection_by_causa_mortis,
        'Year': [2019, 2020, 2021]})

    plt.figure(figsize=(8,6))
    sns.barplot(x='Year', y='Total', data=death_df)   
    plt.title(f'Óbitos por {causa_mortis}')
    plt.show()     
    
    return death_df

# %%
comparison_chart('COVID')
# Out:
#     Total  Year
# 0       0  2019
# 1  197407  2020
# 2  102815  2021

# %%
def comparison_chart(causa_mortis, estado='Brasil'):

    if estado == 'Brasil':
        deaths_by_type_2019 = dados_2019.groupby('tipo_doenca')['total'].sum()
        deaths_by_type_2020 = dados_2020.groupby('tipo_doenca')['total'].sum()
        deaths_by_type_2021 = dados_2021.groupby('tipo_doenca')['total'].sum()
        if(causa_mortis == 'COVID'):
            selection_2019 = 0
        else:
            selection_2019 = int(deaths_by_type_2019.loc[causa_mortis])

        selection_2020 = int(deaths_by_type_2020.loc[causa_mortis])
        selection_2021 = int(deaths_by_type_2021.loc[causa_mortis])
    else:
        deaths_by_type_2019 = dados_2019.groupby(['uf', 'tipo_doenca'])['total'].sum()
        deaths_by_type_2020 = dados_2020.groupby(['uf', 'tipo_doenca'])['total'].sum()
        deaths_by_type_2021 = dados_2021.groupby(['uf', 'tipo_doenca'])['total'].sum()

        if(causa_mortis == 'COVID'):
            selection_2019 = 0
        else:
            selection_2019 = int(deaths_by_type_2019.loc[estado, causa_mortis])

        selection_2020 = int(deaths_by_type_2020.loc[estado, causa_mortis])
        selection_2021 = int(deaths_by_type_2021.loc[estado, causa_mortis])

    selection_by_causa_mortis = [selection_2019, selection_2020, selection_2021]
    
    death_df = pd.DataFrame({'Total': selection_by_causa_mortis,
        'Year': [2019, 2020, 2021]})

    plt.figure(figsize=(8,6))
    sns.barplot(x='Year', y='Total', data=death_df)   
    plt.title(f'Óbitos por {causa_mortis} - {estado}')
    plt.show()     
    
    return death_df

# %%
comparison_chart('COVID', 'MG')
# Out:
#    Total  Year
# 0      0  2019
# 1  14539  2020
# 2  11061  2021

# %%
comparison_chart('PNEUMONIA', 'MG')
# Out:
#    Total  Year
# 0  21255  2019
# 1  19002  2020
# 2   3683  2021
